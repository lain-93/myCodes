# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
url = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'

# %%
dframe_list = pd.io.html.read_html(url)

# %%
dfram = dframe_list[1]
dframe
# Out:
# [                                  0
#  0  Best win–loss record in division,
#      Rank                  Team    GP  Won  Lost  Tied   Pct.  \
#  0      1        Dallas Cowboys   914  520   388     6  0.572
#  1      2     Green Bay Packers  1368  756   574    38  0.567
#  2      3  New England Patriots   916  512   395     9  0.564
#  3      4         Chicago Bears  1402  769   591    42  0.563
#  4      5      Baltimore Ravens   384  214   169     1  0.559
#  5      6        Miami Dolphins   832  457   371     4  0.552
#  6      7     Minnesota Vikings   902  488   403    11  0.547
#  7      8   San Francisco 49ers  1034  545   475    14  0.534
#  8      9       New York Giants  1337  696   608    33  0.533
#  9     10        Denver Broncos   916  483   423    10  0.533
#  10    11    Kansas City Chiefs   916  481   423    12  0.532
#  11    12   Pittsburgh Steelers  1224  636   566    22  0.529
#  12    13    Indianapolis Colts   998  523   468     7  0.528
# ...

# %%
dframe.columns_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-86d070c86200> in <module>
# ----> 1 dframe.columns_values
#
# AttributeError: 'list' object has no attribute 'columns_values'
